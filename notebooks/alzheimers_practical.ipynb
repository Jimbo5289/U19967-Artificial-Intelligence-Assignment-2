# %%
# !git add notebooks/alzheimers_practical.ipynb
# !git commit -m "data: loud dataset and inspect class distribution"
# !git push origin main
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !pwd
# !ls -la
# !git clone https://github.com/Jimbo5289/U19967-Artificial-Intelligence-Assignment-2.git
# Out:
# /content
# total 20
# drwxr-xr-x 1 root root 4096 Dec 30 17:13 .
# drwxr-xr-x 1 root root 4096 Dec 30 15:48 ..
# drwxr-xr-x 4 root root 4096 Dec 11 14:34 .config
# drwxr-xr-x 2 root root 4096 Dec 30 17:13 .ipynb_checkpoints
# drwxr-xr-x 1 root root 4096 Dec 11 14:34 sample_data
# Cloning into 'U19967-Artificial-Intelligence-Assignment-2'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# %cd U19967-Artificial-Intelligence-Assignment-2
# !ls -la
# !git status
# !mkdir -p notebooks src reports/figures outputs models
# %%bash
cat > .gitignore << 'EOF'
__pycache__/
.ipynb_checkpoints/
.DS_Store
# Out:
#   File "/tmp/ipython-input-66751444.py", line 6
#     cat > .gitignore << 'EOF'
#           ^
# SyntaxError: invalid syntax

# %%
# !ls
# Out:
# models	notebooks  outputs  README.md  reports	src

# %%
# %%bash
# cat > .gitignore << 'EOF'
# __pycache__/
# .ipynb_checkpoints/
# .DS_Store
#
# # data / outputs (do not commit Blackboard dataset)
# data/
# dataset/
# outputs/
# runs/
# kt_dir/
#
# # models
# models/
# *.h5
# *.keras
# *.ckpt
# *.pt
# *.pth
# EOF

# %%
# !ls -la
# !cat .gitignore
# Out:
# total 40
# drwxr-xr-x 8 root root 4096 Dec 30 18:13 .
# drwxr-xr-x 1 root root 4096 Dec 30 18:05 ..
# drwxr-xr-x 8 root root 4096 Dec 30 18:08 .git
# -rw-r--r-- 1 root root  183 Dec 30 18:13 .gitignore
# drwxr-xr-x 2 root root 4096 Dec 30 18:08 models
# drwxr-xr-x 2 root root 4096 Dec 30 18:08 notebooks
# drwxr-xr-x 2 root root 4096 Dec 30 18:08 outputs
# -rw-r--r-- 1 root root  116 Dec 30 18:05 README.md
# drwxr-xr-x 3 root root 4096 Dec 30 18:08 reports
# drwxr-xr-x 2 root root 4096 Dec 30 18:08 src
# __pycache__/
# .ipynb_checkpoints/
# .DS_Store
#
# # data / outputs (do not commit Blackboard dataset)
# data/
# dataset/
# outputs/
# runs/
# kt_dir/
#
# # models
# models/
# *.h5
# *.keras
# *.ckpt
# *.pt
# *.pth

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	.gitignore
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add .gitignore
# !git commit -m "chore: add gitignore"
# !git push origin main
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@b5e5a9b57739.(none)')
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git config --global user.name "James Ingleton"
# !git config --global user.email "jamesingleton1971@gmail.com"
# !git config --global --list | grep user
# !git commit -m "chore: add gitignore"
# !git status
# Out:
# user.name=James Ingleton
# user.email=jamesingleton1971@gmail.com
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
import getpass, subprocess

token = getpass.getpass("Paste GitHub PAT (hidden): ")
repo  = "https://github.com/Jimbo5289/U19967-Artificial-Intelligence-Assignment-2.git"
authed = repo.replace("https://", f"https://{token}@")

subprocess.run(["git", "remote", "set-url", "origin", authed], check=True)
print("Remote updated for push (this session).")
# Out:
# Paste GitHub PAT (hidden): ··········
# Remote updated for push (this session).

# %%
# !git push origin main
# Out:
# remote: Permission to Jimbo5289/U19967-Artificial-Intelligence-Assignment-2.git denied to Jimbo5289.
# fatal: unable to access 'https://github.com/Jimbo5289/U19967-Artificial-Intelligence-Assignment-2.git/': The requested URL returned error: 403

# %%
import getpass, subprocess

token = getpass.getpass("Paste GitHub PAT (hidden): ")
user = "Jimbo5289"
repo_path = "Jimbo5289/U19967-Artificial-Intelligence-Assignment-2.git"

authed = f"https://{user}:{token}@github.com/{repo_path}"
subprocess.run(["git", "remote", "set-url", "origin", authed], check=True)
print("Remote updated with username + token.")
# Out:
# Paste GitHub PAT (hidden): ··········
# Remote updated with username + token.

# %%
# !git push origin main
# Out:
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 420 bytes | 420.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/Jimbo5289/U19967-Artificial-Intelligence-Assignment-2.git
#    4b62169..dedfd3f  main -> main

# %%
# !git remote set-url origin https://github.com/Jimbo5289/U19967-Artificial-Intelligence-Assignment-2.git

# %%
# !cp /content/Untitled8.ipynb notebooks/alzheimers_practical.ipynb
# !ls -la notebooks
# Out:
# cp: cannot stat '/content/Untitled8.ipynb': No such file or directory
# total 8
# drwxr-xr-x 2 root root 4096 Dec 30 18:08 .
# drwxr-xr-x 8 root root 4096 Dec 30 18:13 ..

# %%
# !find / -maxdepth 4 -name "*.ipynb" 2>/dev/null

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !find "/content/drive" -name "*.ipynb" | head -n 50
# Out:
# /content/drive/MyDrive/Colab Notebooks/Untitled2.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled3.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled4.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled5.ipynb
# /content/drive/MyDrive/Colab Notebooks/Transfer_LearningMobilenet (1).ipynb
# /content/drive/MyDrive/Colab Notebooks/Transfer_learning.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled0.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled6.ipynb
# /content/drive/MyDrive/Colab Notebooks/Transfer_LearningMobilenet.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled1.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled7.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled8.ipynb
